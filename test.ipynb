# %%
from Methods import Method
import numpy as np
def evaluation(f,x):
    return eval(f)
xi=[0,1,0.8,0.4,2,0.2]
f="np.sin(x)"
fi=evaluation(f,xi)
x=0.52

# %%
app=Method(xi,fi,x)

# %%
app.lagrange()
# Out:
# 0.4968766598868065

# %%
app.PolLagrange().expand()
# Out:
# 0.00600973598834198*x**5 + 0.00459554120126526*x**4 - 0.170052161981573*x**3 + 0.0010193863155763*x**2 + 0.99989848328426*x

# %%
app.newton()
# Out:
# 0.49687665988680646

# %%
app.PolNewton().expand()
# Out:
# 0.00600973598834226*x**5 + 0.00459554120127208*x**4 - 0.170052161981558*x**3 + 0.00101938631557877*x**2 + 0.999898483284261*x

# %%
app.graph("1",f)

# %%
app.graph("2",f)
